# %% [markdown]
# <a href="https://colab.research.google.com/github/agoritma/obesity-prediction/blob/main/obesity_prediction_by_user_behaviour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installing Depedencies

# %%
# !pip install kagglehub

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install kagglehub
# %pip install xgboost

# %% [markdown]
# ## Importing Depedencies

# %%
import pandas as pd
import numpy as np
import kagglehub
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

RANDOM_STATE = 55

# %% [markdown]
# ## Load Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("suleymansulak/obesity-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/suleymansulak/obesity-dataset/versions/1

# %%
df = pd.read_excel(path + "/Obesity_Dataset.xlsx")

# %%
df.head()
# Out:
#    Sex  Age  Height  Overweight_Obese_Family  Consumption_of_Fast_Food  \
# 0    2   18     155                        2                         2
# 1    2   18     158                        2                         2
# 2    2   18     159                        2                         2
# 3    2   18     162                        2                         2
# 4    2   18     165                        2                         1
#
#    Frequency_of_Consuming_Vegetables  Number_of_Main_Meals_Daily  \
# 0                                  3                           1
# 1                                  3                           1
# 2                                  2                           1
# 3                                  2                           2
# 4                                  2                           1
#
#    Food_Intake_Between_Meals  Smoking  Liquid_Intake_Daily  \
# 0                          3        2                    1
# 1                          1        2                    1
# 2                          3        2                    3
# 3                          2        2                    2
# 4                          3        2                    1
#
#    Calculation_of_Calorie_Intake  Physical_Excercise  \
# 0                              2                   3
# 1                              2                   1
# 2                              2                   2
# 3                              2                   1
# 4                              2                   3
#
#    Schedule_Dedicated_to_Technology  Type_of_Transportation_Used  Class
# 0                                 3                            4      2
# 1                                 3                            3      2
# 2                                 3                            4      2
# 3                                 3                            4      2
# 4                                 3                            2      2

# %% [markdown]
# ## Normalize dataset

# %% [markdown]
# ### One Hot

# %%
# Sex column
df['Sex'] = df['Sex'].apply(lambda x: x - 1)

# %%
df["Sex"].unique() # 0:Male 1:Female
# Out:
# array([1, 0])

# %%
df['Overweight_Obese_Family'] = df['Overweight_Obese_Family'].apply(lambda x: 0 if x == 2 else 1)

# %%
df["Overweight_Obese_Family"].unique()
# Out:
# array([0, 1])

# %%
df['Smoking'] = df['Smoking'].apply(lambda x: 0 if x == 2 else 1)

# %%
df["Smoking"].unique()
# Out:
# array([0, 1])

# %%
df['Calculation_of_Calorie_Intake'] = df['Calculation_of_Calorie_Intake'].apply(lambda x: 0 if x == 2 else 1)

# %%
df["Calculation_of_Calorie_Intake"].unique()
# Out:
# array([0, 1])

# %%
oneHotCols = ["Frequency_of_Consuming_Vegetables", "Number_of_Main_Meals_Daily",
                 "Food_Intake_Between_Meals", "Liquid_Intake_Daily", "Physical_Excercise", "Schedule_Dedicated_to_Technology", "Type_of_Transportation_Used"]

# %%
df_onehot = pd.get_dummies(data=df, prefix=oneHotCols, columns=oneHotCols)

# %%
df_onehot.head()
# Out:
#    Sex  Age  Height  Overweight_Obese_Family  Consumption_of_Fast_Food  \
# 0    1   18     155                        0                         2
# 1    1   18     158                        0                         2
# 2    1   18     159                        0                         2
# 3    1   18     162                        0                         2
# 4    1   18     165                        0                         1
#
#    Smoking  Calculation_of_Calorie_Intake  Class  \
# 0        0                              0      2
# 1        0                              0      2
# 2        0                              0      2
# 3        0                              0      2
# 4        0                              0      2
#
#    Frequency_of_Consuming_Vegetables_1  Frequency_of_Consuming_Vegetables_2  \
# 0                                False                                False
# 1                                False                                False
# 2                                False                                 True
# 3                                False                                 True
# 4                                False                                 True
#
#    ...  Physical_Excercise_4  Physical_Excercise_5  \
# 0  ...                 False                 False
# 1  ...                 False                 False
# 2  ...                 False                 False
# 3  ...                 False                 False
# 4  ...                 False                 False
#
#    Schedule_Dedicated_to_Technology_1  Schedule_Dedicated_to_Technology_2  \
# 0                               False                               False
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                               False                               False
#
#    Schedule_Dedicated_to_Technology_3  Type_of_Transportation_Used_1  \
# 0                                True                          False
# 1                                True                          False
# 2                                True                          False
# 3                                True                          False
# 4                                True                          False
#
#    Type_of_Transportation_Used_2  Type_of_Transportation_Used_3  \
# 0                          False                          False
# 1                          False                           True
# 2                          False                          False
# 3                          False                          False
# 4                           True                          False
#
#    Type_of_Transportation_Used_4  Type_of_Transportation_Used_5
# 0                           True                          False
# 1                          False                          False
# 2                           True                          False
# 3                           True                          False
# 4                          False                          False
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Augmented Data

# %%
df_onehot["Growth_Rate"] = df_onehot["Height"] / df_onehot["Age"]
df_onehot
# Out:
#       Sex  Age  Height  Overweight_Obese_Family  Consumption_of_Fast_Food  \
# 0       1   18     155                        0                         2
# 1       1   18     158                        0                         2
# 2       1   18     159                        0                         2
# 3       1   18     162                        0                         2
# 4       1   18     165                        0                         1
# ...   ...  ...     ...                      ...                       ...
# 1605    1   51     165                        0                         1
# 1606    1   51     163                        0                         1
# 1607    1   52     162                        1                         2
# 1608    1   53     168                        0                         1
# 1609    1   54     170                        1                         1
#
#       Smoking  Calculation_of_Calorie_Intake  Class  \
# 0           0                              0      2
# 1           0                              0      2
# 2           0                              0      2
# 3           0                              0      2
# 4           0                              0      2
# ...       ...                            ...    ...
# 1605        1                              1      4
# 1606        0                              0      4
# 1607        1                              1      4
# 1608        1                              0      4
# 1609        1                              0      4
#
#       Frequency_of_Consuming_Vegetables_1  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 1605                                 True
# 1606                                False
# 1607                                 True
# 1608                                 True
# 1609                                 True
#
#       Frequency_of_Consuming_Vegetables_2  ...  Physical_Excercise_5  \
# 0                                   False  ...                 False
# 1                                   False  ...                 False
# 2                                    True  ...                 False
# 3                                    True  ...                 False
# 4                                    True  ...                 False
# ...                                   ...  ...                   ...
# 1605                                False  ...                 False
# 1606                                 True  ...                  True
# 1607                                False  ...                 False
# 1608                                False  ...                 False
# 1609                                False  ...                 False
#
#       Schedule_Dedicated_to_Technology_1  Schedule_Dedicated_to_Technology_2  \
# 0                                  False                               False
# 1                                  False                               False
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
# ...                                  ...                                 ...
# 1605                                True                               False
# 1606                                True                               False
# 1607                                True                               False
# 1608                                True                               False
# 1609                               False                               False
#
#       Schedule_Dedicated_to_Technology_3  Type_of_Transportation_Used_1  \
# 0                                   True                          False
# 1                                   True                          False
# 2                                   True                          False
# 3                                   True                          False
# 4                                   True                          False
# ...                                  ...                            ...
# 1605                               False                           True
# 1606                               False                           True
# 1607                               False                           True
# 1608                               False                           True
# 1609                                True                           True
#
#       Type_of_Transportation_Used_2  Type_of_Transportation_Used_3  \
# 0                             False                          False
# 1                             False                           True
# 2                             False                          False
# 3                             False                          False
# 4                              True                          False
# ...                             ...                            ...
# 1605                          False                          False
# 1606                          False                          False
# 1607                          False                          False
# 1608                          False                          False
# 1609                          False                          False
#
#       Type_of_Transportation_Used_4  Type_of_Transportation_Used_5  \
# 0                              True                          False
# 1                             False                          False
# 2                              True                          False
# 3                              True                          False
# 4                             False                          False
# ...                             ...                            ...
# 1605                          False                          False
# 1606                          False                          False
# 1607                          False                          False
# 1608                          False                          False
# 1609                          False                          False
#
#       Growth_Rate
# 0        8.611111
# 1        8.777778
# 2        8.833333
# 3        9.000000
# 4        9.166667
# ...           ...
# 1605     3.235294
# 1606     3.196078
# 1607     3.115385
# 1608     3.169811
# 1609     3.148148
#
# [1610 rows x 35 columns]

# %%
df_onehot.columns
# Out:
# Index(['Sex', 'Age', 'Height', 'Overweight_Obese_Family',
#        'Consumption_of_Fast_Food', 'Smoking', 'Calculation_of_Calorie_Intake',
#        'Class', 'Frequency_of_Consuming_Vegetables_1',
#        'Frequency_of_Consuming_Vegetables_2',
#        'Frequency_of_Consuming_Vegetables_3', 'Number_of_Main_Meals_Daily_1',
#        'Number_of_Main_Meals_Daily_2', 'Number_of_Main_Meals_Daily_3',
#        'Food_Intake_Between_Meals_1', 'Food_Intake_Between_Meals_2',
#        'Food_Intake_Between_Meals_3', 'Food_Intake_Between_Meals_4',
#        'Liquid_Intake_Daily_1', 'Liquid_Intake_Daily_2',
#        'Liquid_Intake_Daily_3', 'Physical_Excercise_1', 'Physical_Excercise_2',
#        'Physical_Excercise_3', 'Physical_Excercise_4', 'Physical_Excercise_5',
#        'Schedule_Dedicated_to_Technology_1',
#        'Schedule_Dedicated_to_Technology_2',
#        'Schedule_Dedicated_to_Technology_3', 'Type_of_Transportation_Used_1',
#        'Type_of_Transportation_Used_2', 'Type_of_Transportation_Used_3',
#        'Type_of_Transportation_Used_4', 'Type_of_Transportation_Used_5',
#        'Growth_Rate'],
#       dtype='object')

# %% [markdown]
# ## Preparing data for training

# %%
X = df_onehot.drop(["Age", "Height"], axis=1)
y = df["Class"]

# %%
y = y.apply(lambda x: x -1)
y.unique()
# Out:
# array([1, 2, 3, 0])

# %%
X = np.array(X)
X
# Out:
# array([[1, 0, 2, ..., True, False, 8.61111111111111],
#        [1, 0, 2, ..., False, False, 8.777777777777779],
#        [1, 0, 2, ..., True, False, 8.833333333333334],
#        ...,
#        [1, 1, 2, ..., False, False, 3.1153846153846154],
#        [1, 0, 1, ..., False, False, 3.169811320754717],
#        [1, 1, 1, ..., False, False, 3.1481481481481484]], dtype=object)

# %%
y = np.array(y)
y
# Out:
# array([1, 1, 1, ..., 3, 3, 3])

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=RANDOM_STATE)

# %% [markdown]
# ## Training using XGBoost

# %%
xgb_model = XGBClassifier(n_estimators = 200, learning_rate = 0.1,verbosity = 1, random_state = RANDOM_STATE, early_stopping_rounds = 10)
xgb_model.fit(X_train, y_train, eval_set = [(X_val,y_val)])
# Out:
# [0]	validation_0-mlogloss:1.19464
# [1]	validation_0-mlogloss:1.04086
# [2]	validation_0-mlogloss:0.91373
# [3]	validation_0-mlogloss:0.80652
# [4]	validation_0-mlogloss:0.71484
# [5]	validation_0-mlogloss:0.63564
# [6]	validation_0-mlogloss:0.56668
# [7]	validation_0-mlogloss:0.50628
# [8]	validation_0-mlogloss:0.45312
# [9]	validation_0-mlogloss:0.40615
# [10]	validation_0-mlogloss:0.36451
# [11]	validation_0-mlogloss:0.32750
# [12]	validation_0-mlogloss:0.29453
# [13]	validation_0-mlogloss:0.26510
# [14]	validation_0-mlogloss:0.23880
# [15]	validation_0-mlogloss:0.21525
# [16]	validation_0-mlogloss:0.19414
# [17]	validation_0-mlogloss:0.17520
# [18]	validation_0-mlogloss:0.15818
# [19]	validation_0-mlogloss:0.14289
# [20]	validation_0-mlogloss:0.12913
# [21]	validation_0-mlogloss:0.11675
# [22]	validation_0-mlogloss:0.10560
# [23]	validation_0-mlogloss:0.09555
# [24]	validation_0-mlogloss:0.08649
# [25]	validation_0-mlogloss:0.07832
# [26]	validation_0-mlogloss:0.07095
# [27]	validation_0-mlogloss:0.06429
# [28]	validation_0-mlogloss:0.05829
# [29]	validation_0-mlogloss:0.05286
# [30]	validation_0-mlogloss:0.04796
# [31]	validation_0-mlogloss:0.04354
# [32]	validation_0-mlogloss:0.03954
# [33]	validation_0-mlogloss:0.03592
# [34]	validation_0-mlogloss:0.03265
# [35]	validation_0-mlogloss:0.02969
# [36]	validation_0-mlogloss:0.02702
# [37]	validation_0-mlogloss:0.02460
# [38]	validation_0-mlogloss:0.02241
# [39]	validation_0-mlogloss:0.02043
# [40]	validation_0-mlogloss:0.01864
# [41]	validation_0-mlogloss:0.01702
# [42]	validation_0-mlogloss:0.01555
# [43]	validation_0-mlogloss:0.01428
# [44]	validation_0-mlogloss:0.01307
# [45]	validation_0-mlogloss:0.01202
# [46]	validation_0-mlogloss:0.01107
# [47]	validation_0-mlogloss:0.01020
# [48]	validation_0-mlogloss:0.00942
# [49]	validation_0-mlogloss:0.00870
# [50]	validation_0-mlogloss:0.00805
# [51]	validation_0-mlogloss:0.00746
# [52]	validation_0-mlogloss:0.00693
# [53]	validation_0-mlogloss:0.00644
# [54]	validation_0-mlogloss:0.00599
# [55]	validation_0-mlogloss:0.00559
# [56]	validation_0-mlogloss:0.00522
# [57]	validation_0-mlogloss:0.00493
# [58]	validation_0-mlogloss:0.00466
# [59]	validation_0-mlogloss:0.00440
# [60]	validation_0-mlogloss:0.00418
# [61]	validation_0-mlogloss:0.00396
# [62]	validation_0-mlogloss:0.00377
# [63]	validation_0-mlogloss:0.00358
# [64]	validation_0-mlogloss:0.00342
# [65]	validation_0-mlogloss:0.00326
# [66]	validation_0-mlogloss:0.00312
# [67]	validation_0-mlogloss:0.00298
# [68]	validation_0-mlogloss:0.00286
# [69]	validation_0-mlogloss:0.00277
# [70]	validation_0-mlogloss:0.00266
# [71]	validation_0-mlogloss:0.00258
# [72]	validation_0-mlogloss:0.00252
# [73]	validation_0-mlogloss:0.00248
# [74]	validation_0-mlogloss:0.00241
# [75]	validation_0-mlogloss:0.00237
# [76]	validation_0-mlogloss:0.00234
# [77]	validation_0-mlogloss:0.00230
# [78]	validation_0-mlogloss:0.00227
# [79]	validation_0-mlogloss:0.00224
# [80]	validation_0-mlogloss:0.00221
# [81]	validation_0-mlogloss:0.00216
# [82]	validation_0-mlogloss:0.00213
# [83]	validation_0-mlogloss:0.00213
# [84]	validation_0-mlogloss:0.00212
# [85]	validation_0-mlogloss:0.00211
# [86]	validation_0-mlogloss:0.00211
# [87]	validation_0-mlogloss:0.00210
# [88]	validation_0-mlogloss:0.00209
# [89]	validation_0-mlogloss:0.00209
# [90]	validation_0-mlogloss:0.00208
# [91]	validation_0-mlogloss:0.00208
# [92]	validation_0-mlogloss:0.00207
# [93]	validation_0-mlogloss:0.00207
# [94]	validation_0-mlogloss:0.00206
# [95]	validation_0-mlogloss:0.00206
# [96]	validation_0-mlogloss:0.00205
# [97]	validation_0-mlogloss:0.00205
# [98]	validation_0-mlogloss:0.00205
# [99]	validation_0-mlogloss:0.00204
# [100]	validation_0-mlogloss:0.00204
# [101]	validation_0-mlogloss:0.00203
# [102]	validation_0-mlogloss:0.00201
# [103]	validation_0-mlogloss:0.00200
# [104]	validation_0-mlogloss:0.00200
# [105]	validation_0-mlogloss:0.00200
# [106]	validation_0-mlogloss:0.00199
# [107]	validation_0-mlogloss:0.00199
# [108]	validation_0-mlogloss:0.00199
# [109]	validation_0-mlogloss:0.00199
# [110]	validation_0-mlogloss:0.00198
# [111]	validation_0-mlogloss:0.00198
# [112]	validation_0-mlogloss:0.00198
# [113]	validation_0-mlogloss:0.00198
# [114]	validation_0-mlogloss:0.00197
# [115]	validation_0-mlogloss:0.00197
# [116]	validation_0-mlogloss:0.00197
# [117]	validation_0-mlogloss:0.00197
# [118]	validation_0-mlogloss:0.00196
# [119]	validation_0-mlogloss:0.00196
# [120]	validation_0-mlogloss:0.00196
# [121]	validation_0-mlogloss:0.00196
# [122]	validation_0-mlogloss:0.00196
# [123]	validation_0-mlogloss:0.00196
# [124]	validation_0-mlogloss:0.00195
# [125]	validation_0-mlogloss:0.00195
# [126]	validation_0-mlogloss:0.00195
# [127]	validation_0-mlogloss:0.00195
# [128]	validation_0-mlogloss:0.00195
# [129]	validation_0-mlogloss:0.00194
# [130]	validation_0-mlogloss:0.00194
# [131]	validation_0-mlogloss:0.00194
# [132]	validation_0-mlogloss:0.00194
# [133]	validation_0-mlogloss:0.00194
# [134]	validation_0-mlogloss:0.00194
# [135]	validation_0-mlogloss:0.00193
# [136]	validation_0-mlogloss:0.00193
# [137]	validation_0-mlogloss:0.00193
# [138]	validation_0-mlogloss:0.00193
# [139]	validation_0-mlogloss:0.00193
# [140]	validation_0-mlogloss:0.00192
# [141]	validation_0-mlogloss:0.00192
# [142]	validation_0-mlogloss:0.00192
# [143]	validation_0-mlogloss:0.00192
# [144]	validation_0-mlogloss:0.00192
# [145]	validation_0-mlogloss:0.00192
# [146]	validation_0-mlogloss:0.00192
# [147]	validation_0-mlogloss:0.00192
# [148]	validation_0-mlogloss:0.00191
# [149]	validation_0-mlogloss:0.00191
# [150]	validation_0-mlogloss:0.00191
# [151]	validation_0-mlogloss:0.00191
# [152]	validation_0-mlogloss:0.00191
# [153]	validation_0-mlogloss:0.00191
# [154]	validation_0-mlogloss:0.00191
# [155]	validation_0-mlogloss:0.00191
# [156]	validation_0-mlogloss:0.00191
# [157]	validation_0-mlogloss:0.00190
# [158]	validation_0-mlogloss:0.00190
# [159]	validation_0-mlogloss:0.00190
# [160]	validation_0-mlogloss:0.00190
# [161]	validation_0-mlogloss:0.00190
# [162]	validation_0-mlogloss:0.00190
# [163]	validation_0-mlogloss:0.00190
# [164]	validation_0-mlogloss:0.00190
# [165]	validation_0-mlogloss:0.00190
# [166]	validation_0-mlogloss:0.00190
# [167]	validation_0-mlogloss:0.00190
# [168]	validation_0-mlogloss:0.00189
# [169]	validation_0-mlogloss:0.00189
# [170]	validation_0-mlogloss:0.00189
# [171]	validation_0-mlogloss:0.00189
# [172]	validation_0-mlogloss:0.00189
# [173]	validation_0-mlogloss:0.00189
# [174]	validation_0-mlogloss:0.00189
# [175]	validation_0-mlogloss:0.00189
# [176]	validation_0-mlogloss:0.00189
# [177]	validation_0-mlogloss:0.00189
# [178]	validation_0-mlogloss:0.00188
# [179]	validation_0-mlogloss:0.00188
# [180]	validation_0-mlogloss:0.00188
# [181]	validation_0-mlogloss:0.00188
# [182]	validation_0-mlogloss:0.00188
# [183]	validation_0-mlogloss:0.00188
# [184]	validation_0-mlogloss:0.00188
# [185]	validation_0-mlogloss:0.00188
# [186]	validation_0-mlogloss:0.00188
# [187]	validation_0-mlogloss:0.00188
# [188]	validation_0-mlogloss:0.00188
# [189]	validation_0-mlogloss:0.00188
# [190]	validation_0-mlogloss:0.00188
# [191]	validation_0-mlogloss:0.00188
# [192]	validation_0-mlogloss:0.00187
# [193]	validation_0-mlogloss:0.00187
# [194]	validation_0-mlogloss:0.00187
# [195]	validation_0-mlogloss:0.00187
# [196]	validation_0-mlogloss:0.00187
# [197]	validation_0-mlogloss:0.00187
# [198]	validation_0-mlogloss:0.00187
# [199]	validation_0-mlogloss:0.00187
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
xgb_model.best_iteration
# Out:
# 199

# %%
print(f"Metrics train:\n\tAccuracy score: {accuracy_score(xgb_model.predict(X_train),y_train):.4f}\nMetrics test:\n\tAccuracy score: {accuracy_score(xgb_model.predict(X_val),y_val):.4f}")
# Out:
# Metrics train:
# 	Accuracy score: 1.0000
# Metrics test:
# 	Accuracy score: 1.0000

# %% [markdown]
# ## Testing the model

# %%
classMap = {
    0: "Underweigth",
    1: "Normal",
    2: "Overweight",
    3: "Obesity",
}

# %%
import random

# %%
index = random.randint(0, len(X_val)-1)

data = np.array(X_val)
data = data[index]
ground = np.array(y_val)
ground = ground[index]

predict = xgb_model.predict(data.reshape(1, -1))

print("Ground Thruth:" , classMap[ground])
print("Prediction: ", classMap[predict[0]])
# Out:
# Ground Thruth: Normal
# Prediction:  Normal
